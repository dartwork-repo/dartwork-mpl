# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import matplotlib as mpl
import dartwork_mpl as dmpl

# %%
fig, axs = dmpl.util.plot_colormaps()

# %%
dmpl.save_formats(fig, 'colormaps', ['png'])
