# %% [markdown]
# # Compositing Styles

# %% [markdown]
# 일반적으로 통일된 스타일 내에서 목적에 따라 폰트 크기, 폰트 종류, 그리고 기타 세부 요소들이 변경됩니다.
#
# 이러한 기능을 명확하게 사용할 수 있도록 각 요소를 개별적으로 정의하여 모듈화된 형태로 로드하고 사용할 수 있게 설계되었습니다.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import dartwork_mpl as dm
# Out:
# Load colors...
# Load colormaps...

# %%
# 예시를 위한 시각화 함수.
def plot_example():
    # Create some sample data
    x = np.linspace(0, 10, 100)
    y1 = np.sin(x)
    y2 = np.cos(x)
    y3 = np.sin(x) * np.exp(-0.2 * x)
    
    # Create a figure with subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(5, 6))
    
    # Plot on first subplot
    ax1.plot(x, y1, label='sin(x)')
    ax1.plot(x, y2, label='cos(x)')
    ax1.set_title('Trigonometric Functions')
    ax1.set_xlabel('x')
    ax1.set_ylabel('y')
    ax1.legend()
    ax1.grid(True)
    
    # Plot on second subplot
    ax2.plot(x, y3, label='sin(x) * exp(-0.2x)')
    ax2.fill_between(x, 0, y3, alpha=0.3)
    ax2.set_title('Damped Sine Wave')
    ax2.set_xlabel('x')
    ax2.set_ylabel('Amplitude')
    ax2.legend()
    
    # Add a scatter plot with different marker sizes
    sizes = np.linspace(10, 100, 10)
    x_scatter = np.linspace(1, 9, 10)
    y_scatter = np.sin(x_scatter) * np.exp(-0.2 * x_scatter)
    ax2.scatter(x_scatter, y_scatter, s=sizes, alpha=0.6)
    
    dm.simple_layout(fig)
    dm.save_and_show(fig)

# %% [markdown]
# ## 가능한 스타일 목록

# %% [markdown]
# 아래 스타일을 조합하여 사용할 수 있습니다.
#
# `dmpl`과 `dmpl-light`는 backward compatibility를 위한 스타일입니다. 사용하지 않아도 됩니다.

# %%
dm.list_styles()
# Out:
# ['base',
#  'dmpl',
#  'dmpl_light',
#  'font-investment',
#  'font-presentation',
#  'font-scientific',
#  'lang-kr',
#  'spine-no',
#  'spine-yes']

# %% [markdown]
# ## 스타일 적용 후 그래프 그리기

# %%
# 기본 스타일 적용.
dm.style.use(['base'])
plot_example()
# Out:
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="600pt" height="720pt" viewBox="0 0 360 432" version="1.1">
#  <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2025-03-12T22:39:42.097234</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.10.0, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 432  L 360 432  L 360 0  L 0 0  z " style="fill: #ffffff"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 34.563557 193.816857  L 351.032701 193.816857  L 351.032701 15.73445  L 34.563557 15.73445  z " style="fill: #ffffff"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 34.563557 193.816857  L 34.563557 15.73445  " clip-path="url(#p1f3ea6e2df)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="m680d7f02a8" d="M 0 0  L 0 2  " style="stroke: #000000; stroke-width: 0.3"/>
#       </defs>
#       <g>
#        <use xlink:href="#m680d7f02a8" x="34.563557" y="193.816857" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <g transform="translate(32.623791 203.066857) scale(0.07 -0.07)">
#        <defs>
#         <path id="Roboto-Light-30" d="M 3172 1897  Q 3172 934 2819 435  Q 2466 -63 1778 -63  Q 1103 -63 743 426  Q 384 916 375 1850  L 375 2666  Q 375 3625 731 4119  Q 1088 4613 1772 4613  Q 2447 4613 2803 4136  Q 3159 3659 3172 2731  L 3172 1897  z M 2797 2713  Q 2797 3494 2542 3894  Q 2288 4294 1772 4294  Q 1266 4294 1009 3903  Q 753 3513 747 2750  L 747 1856  Q 747 1078 1011 665  Q 1275 253 1778 253  Q 2278 253 2536 656  Q 2794 1059 2797 1838  L 2797 2713  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 97.857386 193.816857  L 97.857386 15.73445  " clip-path="url(#p1f3ea6e2df)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#m680d7f02a8" x="97.857386" y="193.816857" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2 -->
#       <g transform="translate(95.91762 203.066857) scale(0.07 -0.07)">
#        <defs>
#         <path id="Roboto-Light-32" d="M 3278 0  L 428 0  L 428 288  L 1988 2056  Q 2375 2503 2525 2793  Q 2675 3084 2675 3359  Q 2675 3791 2422 4042  Q 2169 4294 1725 4294  Q 1266 4294 983 4000  Q 700 3706 700 3238  L 328 3238  Q 328 3622 501 3937  Q 675 4253 995 4433  Q 1316 4613 1725 4613  Q 2350 4613 2701 4284  Q 3053 3956 3053 3391  Q 3053 3072 2854 2694  Q 2656 2316 2156 1750  L 888 316  L 3278 316  L 3278 0  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 161.151215 193.816857  L 161.151215 15.73445  " clip-path="url(#p1f3ea6e2df)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#m680d7f02a8" x="161.151215" y="193.816857" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 4 -->
#       <g transform="translate(159.211449 203.066857) scale(0.07 -0.07)">
#        <defs>
#         <path id="Roboto-Light-34" d="M 2725 1466  L 3434 1466  L 3434 1150  L 2725 1150  L 2725 0  L 2350 0  L 2350 1150  L 209 1150  L 209 1363  L 2316 4550  L 2725 4550  L 2725 1466  z M 669 1466  L 2350 1466  L 2350 4066  L 2184 3778  L 669 1466  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path d="M 224.445044 193.816857  L 224.445044 15.73445  " clip-path="url(#p1f3ea6e2df)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use xlink:href="#m680d7f02a8" x="224.445044" y="193.816857" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 6 -->
#       <g transform="translate(222.505278 203.066857) scale(0.07 -0.07)">
#        <defs>
#         <path id="Roboto-Light
" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_12">
#       <g>
#        <use xlink:href="#m76cb809613" x="351.032701" y="193.816857" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 10 -->
#       <g transform="translate(347.15317 203.066857) scale(0.07 -0.07)">
#        <defs>
#         <path id="Roboto-Light-31" d="M 2169 0  L 1794 0  L 1794 4100  L 556 3641  L 556 3991  L 2106 4566  L 2169 4566  L 2169 0  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-31"/>
#        <use xlink:href="#Roboto-Light-30" transform="translate(55.419922 0)"/>
#       </g>
#      </g>
#     </g>
#     <g id="text_7">
#      <!-- x -->
#      <g transform="translate(190.974106 214.113732) scale(0.075 -0.075)">
#       <defs>
#        <path id="Roboto-Light-78" d="M 1550 2009  L 2463 3381  L 2906 3381  L 175

# %% [markdown]
# ## Presentation type

# %% [markdown]
# 기본 스타일에서 폰트 크기만 변경되었기 때문에 그래프 모양은 동일합니다.
#
# 해당 스타일에 어떤 값들이 정의되어 있는지 확인하는 함수는 `dm.load_style_dict('font-presentation')` 입니다.

# %%
dm.load_style_dict('font-presentation')
# Out:
# {'font.family': 'roboto',
#  'font.weight': 300.0,
#  'font.size': 8.5,
#  'mathtext.fontset': 'custom',
#  'mathtext.bf': 'Noto',
#  'mathtext.it': 'Noto',
#  'mathtext.rm': 'Noto',
#  'mathtext.sf': 'Noto',
#  'mathtext.tt': 'Noto',
#  'mathtext.fallback': 'None',
#  'mathtext.default': 'it',
#  'axes.titlesize': 9.5,
#  'axes.titleweight': 400.0,
#  'axes.labelsize': 8.5,
#  'axes.labelweight': 300.0,
#  'axes.xmargin': 0.0,
#  'axes.ymargin': 0.0,
#  'axes.zmargin': 0.0,
#  'xtick.labelsize': 8.0,
#  'ytick.labelsize': 8.0,
#  'legend.fontsize': 6.5,
#  'figure.titleweight': 400.0,
#  'figure.labelsize': 8.5,
#  'figure.labelweight': 300.0}

# %%
# 기본 스타일 적용 후 presentation 폰트 크기 사용.
dm.style.use([
    'base',
    # 'spine-no',
    'font-presentation',
])
plot_example()
# Out:
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="600pt" height="720pt" viewBox="0 0 360 432" version="1.1">
#  <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2025-03-12T22:40:17.133985</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.10.0, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 432  L 360 432  L 360 0  L 0 0  z " style="fill: #ffffff"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 38.159238 193.543835  L 350.391291 193.543835  L 350.391291 16.906275  L 38.159238 16.906275  z " style="fill: #ffffff"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 38.159238 193.543835  L 38.159238 16.906275  " clip-path="url(#pc3799e6d36)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="m9c29c5728b" d="M 0 0  L 0 2  " style="stroke: #000000; stroke-width: 0.3"/>
#       </defs>
#       <g>
#        <use xlink:href="#m9c29c5728b" x="38.159238" y="193.543835" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <g transform="translate(35.942363 203.543835) scale(0.08 -0.08)">
#        <defs>
#         <path id="Roboto-Light-30" d="M 3172 1897  Q 3172 934 2819 435  Q 2466 -63 1778 -63  Q 1103 -63 743 426  Q 384 916 375 1850  L 375 2666  Q 375 3625 731 4119  Q 1088 4613 1772 4613  Q 2447 4613 2803 4136  Q 3159 3659 3172 2731  L 3172 1897  z M 2797 2713  Q 2797 3494 2542 3894  Q 2288 4294 1772 4294  Q 1266 4294 1009 3903  Q 753 3513 747 2750  L 747 1856  Q 747 1078 1011 665  Q 1275 253 1778 253  Q 2278 253 2536 656  Q 2794 1059 2797 1838  L 2797 2713  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 100.605649 193.543835  L 100.605649 16.906275  " clip-path="url(#pc3799e6d36)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#m9c29c5728b" x="100.605649" y="193.543835" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2 -->
#       <g transform="translate(98.388774 203.543835) scale(0.08 -0.08)">
#        <defs>
#         <path id="Roboto-Light-32" d="M 3278 0  L 428 0  L 428 288  L 1988 2056  Q 2375 2503 2525 2793  Q 2675 3084 2675 3359  Q 2675 3791 2422 4042  Q 2169 4294 1725 4294  Q 1266 4294 983 4000  Q 700 3706 700 3238  L 328 3238  Q 328 3622 501 3937  Q 675 4253 995 4433  Q 1316 4613 1725 4613  Q 2350 4613 2701 4284  Q 3053 3956 3053 3391  Q 3053 3072 2854 2694  Q 2656 2316 2156 1750  L 888 316  L 3278 316  L 3278 0  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 163.052059 193.543835  L 163.052059 16.906275  " clip-path="url(#pc3799e6d36)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#m9c29c5728b" x="163.052059" y="193.543835" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 4 -->
#       <g transform="translate(160.835184 203.543835) scale(0.08 -0.08)">
#        <defs>
#         <path id="Roboto-Light-34" d="M 2725 1466  L 3434 1466  L 3434 1150  L 2725 1150  L 2725 0  L 2350 0  L 2350 1150  L 209 1150  L 209 1363  L 2316 4550  L 2725 4550  L 2725 1466  z M 669 1466  L 2350 1466  L 2350 4066  L 2184 3778  L 669 1466  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path d="M 225.49847 193.543835  L 225.49847 16.906275  " clip-path="url(#pc3799e6d36)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use xlink:href="#m9c29c5728b" x="225.49847" y="193.543835" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 6 -->
#       <g transform="translate(223.281595 203.543835) scale(0.08 -0.08)">
#        <defs>
#         <path id="Roboto-Light-36" d="M 2634 4584  L 2634 4256  L 2591 4256  Q 1775 4256 1306 3776  Q 838 3297 788 2444  Q 975 2703 1265 2845  Q 1556 2988 1916 2988  Q 2516 2988 2870 2573  Q 3225 2159 3225 1491  Q 3225 1047 3059 690  Q 2894 334 2584 135  Q 2275 -63 1878 -63  Q 1225 -63 815 410  Q 406 884 406 1634  L 406 2009  Q 406 3231 962 3901  Q 1519 4572 2541 4584  L 2634 4584  z M 1856 2666  Q 1500 2666 1192 2455  Q 884 2244 781 1919  L 781 1600  Q 781 1006 1086 631  Q 1391 256 1878 256  Q 2316 256 2586 603  Q 2856 950 2856 1478  Q 2856 2016 2586 2341  Q 2316 2666 1856 2666  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path d="M 287.944881 193.543835  L 287.944881 16.906275  " clip-path="url(#pc3799e6d36)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_10">
#       <g>
#        <use xlink:href="#m9c29c5728b" x="287.944881" y="193.543835" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 8 -->
#       <g transform="translate(285.728006 203.543835) scale(0.08 -0.08)">
#        <defs>
#         <path id="Roboto-Light-38" d="M 3109 3378  Q 3109 3025 2903 2745  Q 2697 2466 2359 2334  Q 2753 2200 2990 1900  Q 3228 1600 3228 1206  Q 3228 622 2831 279  Q 2434 -63 1781 -63  Q 1122 -63 726 278  Q 331 619 331 1206  Q 331 1594 559 1897  Q 788 2200 1184 2334  Q 847 2466 647 2745  Q 447 3025 447 3378  Q 447 3944 811 4278  Q 1175 4613 1775 4613  Q 2375 4613 2742 4275  Q 3109 3938 3109 3378  z M 2853 1203  Q 2853 1628 2550 1901  Q 2247 2175 1775 2175  Q 1303 2175 1003 1906  Q 703 1638 703 1203  Q 703 769 993 511  Q 1284 253 1781 253  Q 2266 253 2559 509  Q 2853 766 2853 1203  z M 2734 3381  Q 2734 3772 2464 4033  Q 2194 4294 1775 4294  Q 1350 4294 1086 4042  Q 822 3791 822 3381  Q 822 2981 1086 2737  Q 1350 2494 1778 2494  Q 2200 2494 2467 2739  Q 2734 2984 2734 3381  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-38"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_11">
#       <path d="M 350.391291 193.543835  L 350.391291 16.906275  " clip-path="url(#pc3799e6d36)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_12">
#       <g>
#        <use xlink:href="#m9c29c5728b" x="350.391291" y="193.543835" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 10 -->
#       <g transform="translate(345.957541 203.543835) scale(0.08 -0.08)">
#        <defs>
#         <path id="Roboto-Light-31" d="M 2169 0  L 1794 0  L 1794 4100  L 556 3641  L 556 3991  L 2106 4566  L 2169 4566  L 2169 0  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Roboto-Light-31"/>
#        <use xlink:href="#Roboto-Light-30" transform="translate(55.419922 0)"/>
#       </g>
#      </g>
#     </g>
#     <g id="text_7">
#      <!-- x -->
#      <g transform="translate(192.208038 215.543835) scale(0.085 -0.085)">
#       <defs>
#        <path id="Roboto-Light-78" d="M 1550 2009  L 2463 3381  L 2906 3

# %% [markdown]
# ## 한국어 지원
#
# 지금의 구현은 한국어 지원을 위해 폰트 타입을 변경하는 것이 전부입니다.

# %%
dm.load_style_dict('lang-kr')
# Out:
# {'font.family': 'paperlogy'}

# %%
dm.style.use([
    'base',
    # 'spine-no',
    'font-presentation',
    'lang-kr',
])
plot_example()
# Out:
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="600pt" height="720pt" viewBox="0 0 360 432" version="1.1">
#  <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2025-03-12T22:40:24.127247</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.10.0, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 432  L 360 432  L 360 0  L 0 0  z " style="fill: #ffffff"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 42.210618 192.910391  L 349.68603 192.910391  L 349.68603 17.156106  L 42.210618 17.156106  z " style="fill: #ffffff"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 42.210618 192.910391  L 42.210618 17.156106  " clip-path="url(#pf0e31bfe1e)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="m8c37d7eb62" d="M 0 0  L 0 2  " style="stroke: #000000; stroke-width: 0.3"/>
#       </defs>
#       <g>
#        <use xlink:href="#m8c37d7eb62" x="42.210618" y="192.910391" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <g transform="translate(39.543743 203.505391) scale(0.08 -0.08)">
#        <defs>
#         <path id="Paperlogy-3Light-30" d="M 2133 -36  Q 1565 -36 1117 273  Q 669 583 420 1155  Q 171 1728 171 2489  Q 171 3257 420 3826  Q 669 4395 1117 4704  Q 1565 5013 2133 5013  Q 2709 5013 3153 4704  Q 3598 4395 3847 3826  Q 4096 3257 4096 2489  Q 4096 1728 3847 1155  Q 3598 583 3153 273  Q 2709 -36 2133 -36  z M 2133 334  Q 2603 334 2955 590  Q 3307 846 3502 1333  Q 3698 1820 3698 2489  Q 3698 3157 3502 3648  Q 3307 4139 2955 4395  Q 2603 4651 2133 4651  Q 1671 4651 1319 4395  Q 967 4139 775 3648  Q 583 3157 583 2489  Q 583 1820 775 1333  Q 967 846 1319 590  Q 1671 334 2133 334  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Paperlogy-3Light-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 103.7057 192.910391  L 103.7057 17.156106  " clip-path="url(#pf0e31bfe1e)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#m8c37d7eb62" x="103.7057" y="192.910391" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 2 -->
#       <g transform="translate(101.038825 203.505391) scale(0.08 -0.08)">
#        <defs>
#         <path id="Paperlogy-3Light-32" d="M 3861 0  L 413 0  L 413 284  L 2510 2368  Q 2923 2773 3068 3061  Q 3214 3349 3214 3655  Q 3214 4124 2894 4387  Q 2574 4651 1977 4651  Q 1053 4651 562 4075  L 277 4302  Q 555 4651 996 4832  Q 1437 5013 2005 5013  Q 2745 5013 3179 4657  Q 3613 4302 3613 3684  Q 3613 3300 3445 2951  Q 3278 2603 2809 2148  L 1017 363  L 3861 363  L 3861 0  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Paperlogy-3Light-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 165.200782 192.910391  L 165.200782 17.156106  " clip-path="url(#pf0e31bfe1e)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#m8c37d7eb62" x="165.200782" y="192.910391" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 4 -->
#       <g transform="translate(162.533907 203.505391) scale(0.08 -0.08)">
#        <defs>
#         <path id="Paperlogy-3Light-34" d="M 3328 1365  L 3328 0  L 2930 0  L 2930 1365  L 107 1365  L 107 1657  L 2795 4978  L 3243 4978  L 619 1721  L 2937 1721  L 2937 2930  L 3328 2930  L 3328 1721  L 4366 1721  L 4366 1365  L 3328 1365  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Paperlogy-3Light-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_7">
#       <path d="M 226.695865 192.910391  L 226.695865 17.156106  " clip-path="url(#pf0e31bfe1e)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use xlink:href="#m8c37d7eb62" x="226.695865" y="192.910391" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 6 -->
#       <g transform="translate(224.02899 203.505391) scale(0.08 -0.08)">
#        <defs>
#         <path id="Paperlogy-3Light-36" d="M 2347 2958  Q 2837 2958 3217 2777  Q 3598 2596 3808 2261  Q 4018 1927 4018 1479  Q 4018 1024 3801 682  Q 3584 341 3203 152  Q 2823 -36 2347 -36  Q 1373 -36 853 622  Q 334 1280 334 2460  Q 334 3285 611 3857  Q 889 4430 1390 4721  Q 1892 5013 2560 5013  Q 3285 5013 3712 4743  L 3541 4430  Q 3193 4658 2567 4658  Q 1721 4658 1234 4110  Q 747 3563 747 2517  Q 747 2261 789 1948  Q 939 2425 1362 2691  Q 1785 2958 2347 2958  z M 2333 306  Q 2909 306 3264 622  Q 3620 939 3620 1465  Q 3620 1991 3260 2304  Q 2901 2617 2290 2617  Q 1892 2617 1586 2464  Q 1280 2311 1109 2044  Q 939 1778 939 1451  Q 939 1159 1099 896  Q 1259 633 1575 469  Q 1892 306 2333 306  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Paperlogy-3Light-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_9">
#       <path d="M 288.190947 192.910391  L 288.190947 17.156106  " clip-path="url(#pf0e31bfe1e)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_10">
#       <g>
#        <use xlink:href="#m8c37d7eb62" x="288.190947" y="192.910391" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 8 -->
#       <g transform="translate(285.524072 203.505391) scale(0.08 -0.08)">
#        <defs>
#         <path id="Paperlogy-3Light-38" d="M 2965 2603  Q 3477 2468 3758 2148  Q 4039 1828 4039 1372  Q 4039 718 3527 341  Q 3015 -36 2133 -36  Q 1252 -36 743 341  Q 235 718 235 1372  Q 235 1835 512 2151  Q 789 2468 1301 2603  Q 875 2745 644 3029  Q 413 3314 413 3719  Q 413 4316 882 4664  Q 1351 5013 2133 5013  Q 2916 5013 3388 4664  Q 3861 4316 3861 3719  Q 3861 3314 3630 3029  Q 3399 2745 2965 2603  z M 2133 4679  Q 1529 4679 1173 4416  Q 818 4153 818 3712  Q 818 3271 1163 3015  Q 1508 2759 2133 2759  Q 2752 2759 3107 3015  Q 3463 3271 3463 3712  Q 3463 4153 3104 4416  Q 2745 4679 2133 4679  z M 2133 306  Q 2837 306 3235 594  Q 3634 882 3634 1372  Q 3634 1863 3235 2147  Q 2837 2432 2133 2432  Q 1429 2432 1038 2147  Q 647 1863 647 1372  Q 647 875 1038 590  Q 1429 306 2133 306  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Paperlogy-3Light-38"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_11">
#       <path d="M 349.68603 192.910391  L 349.68603 17.156106  " clip-path="url(#pf0e31bfe1e)" style="fill: none; stroke: #dee2e6; stroke-width: 0.3; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_12">
#       <g>
#        <use xlink:href="#m8c37d7eb62" x="349.68603" y="192.910391" style="stroke: #000000; stroke-width: 0.3"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 10 -->
#       <g transform="translate(344.35228 203.505391) scale(0.08 -0.08)">
#        <defs>
#         <path id="Paperlogy-3Light-31" d="M 2546 0  L 2148 0  L 2148 4622  L 939 4622  L 939 4978  L 2546 4978  L 2546 0  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#Paperlogy-3Light-31"/>
#        <use xlink:href="#Paperlogy-3Light-30" transform="translate(66.666656 0)"/>
#       </g>
#      </g

# %% [markdown]
# ## Style file 위치
#
# `dm.style_path('base')`를 통해 스타일의 위치를 확인할 수 있습니다.

# %%
dm.style_path('base')
# Out:
# PosixPath('/Users/lsw91/Workspace/dartwork-mpl/src/dartwork_mpl/asset/mplstyle/base.mplstyle')
